# %%
import pandas as pd
import psycopg2
from psycopg2 import sql
import numpy as np
import psycopg2.extras as extras

# %% [markdown]
# ## CONFIGURATION

# %%
CSV_FILE = '../data/sales.csv'
DB_NAME = 'sales_db'
DB_USER = 'postgres'
DB_PASSWORD = 'Maleek11'
DB_HOST = 'localhost'
DB_PORT = '5432'
TARGET_TABLE = 'etl_transformed_sales'

# %% [markdown]
# ## DB CONNECTION

# %%
# Establish Connection to PostgreSQL Database
try:
    conn = psycopg2.connect(
        dbname = DB_NAME,
        user = DB_USER,
        password = DB_PASSWORD,
        host = DB_HOST,
        port = DB_PORT
    )
    print(f"Successfully connected to PostgreSQL database: {DB_NAME}")

except psycopg2.Error as e:
    print(f'Database connection failed. Error at {e}')
    print("Please check your database service and credentials")
# Out:
# Successfully connected to PostgreSQL database: sales_db

# %% [markdown]
# ## CREATE TABLE

# %%
# Create the target table structure in POstgreSQL if it doesn't exist

create_table_query = sql.SQL(f"""
        CREATE TABLE IF NOT EXISTS {TARGET_TABLE}(
            order_id INTEGER UNIQUE,
            product VARCHAR(255),
            category VARCHAR(100),
            sales_amount NUMERIC(10,2),
            order_date DATE,
            region VARCHAR(50),
            customer_name VARCHAR(255),
            unit_price NUMERIC(10,2), -- Transformed column
            sales_tier VARCHAR(50), --Transformed column
            load_timestamp TIMESTAMP WITH TIME ZONE DEFAULT CURRENT_TIMESTAMP
            );
""")

try:
    with conn.cursor() as cur:
        cur.execute(create_table_query)
        conn.commit()
    print(f'Table {TARGET_TABLE} already exists or has been successfully created')
except psycopg2.Error as e:
    print(f'Error creating table: {e}')
    conn.rollback()
# Out:
# Table etl_transformed_sales already exists or has been successfully created

# %% [markdown]
# ## EXTRACT DATA

# %%
# Extract Data (E)
print("---Step 1: Extraction (E) ---")

try:
    # Read the CSV file into a Pandas DataFrame
    df =pd.read_csv(CSV_FILE)
    print(f'Data extracted successfully from {CSV_FILE}.')
    print(f'Initial DataFrame shape: {df.shape}')
    print('\nInitial Data Head:')
    display(df.head())
except FileNotFoundError:
    print(f'Error: The file {CSV_FILE} was not found. Make sure it is in the same directory')
    df=None
except Exception as e:
    print(f'Error during CSV read@ {e}')
    df=None

if df is None:
    raise SystemExit('Exiting ETL process due to extraction failure.')
# Out:
# ---Step 1: Extraction (E) ---
# Data extracted successfully from ../data/sales.csv.
# Initial DataFrame shape: (12, 7)
#
# Initial Data Head:
#    OrderId               Product     Category  SalesAmount   OrderDate  \
# 0     1001         Laptop Pro 13  Electronics       1000.0  05/01/2025
# 1     1002   Mechanical Keyboard  Electronics         95.5  06/01/2025
# 2     1003  Desk Chair Ergonomic    Furniture        350.0  06/01/2025
# 3     1004   Coffee Maker Deluxe   Home Goods        150.0  07/01/2025
# 4     1005        Wireless Mouse  Electronics         25.0  07/01/2025
#
#     Region   CustomerName
# 0     West  Alice Johnson
# 1     East      Bob Smith
# 2     West  Charlie Brown
# 3  Central   Diana Prince
# 4     East    Evan Peters

# %% [markdown]
# # DATA TRANSFORMATION

# %%
# --- 2. TRANSFORMATION (T) ---
print('\n--- 2. TRANSFORMATION (T) --- ')

# T1: Clean column names (lowercase and replace spaces/special chars)
df.columns = df.columns.str.replace(' ','_').str.replace(r'([A-Z])',r'_\1', regex=True).str.lower().str.strip('_')
print('Column names cleaned')
print(f'New columns: {df.columns.tolist()}')
# Out:
# --- 2. TRANSFORMATION (T) ---
# Column names cleaned
# New columns: ['order_id', 'product', 'category', 'sales_amount', 'order_date', 'region', 'customer_name']

# %%
# T2: Data Type Conversion
# Convert OrderDate to datetime objects
df['order_date'] = pd.to_datetime(df['order_date'])
# Ensure SalesAmount is numeric (it should be, but good practice)
df['sales_amount'] = pd.to_numeric(df['sales_amount'])
#df['sales_amount'] = abs(df['sales_amount'])
print('Data types adjusted (OrderDate to datetime, SalesAmount to numeric)')
#print('Replaced negative sales_amount with an absolute value')
# Out:
# Data types adjusted (OrderDate to datetime, SalesAmount to numeric)

# %%
# T3: Derived Column Creation (Unit Price)
# For this simple example, we will assume every sale is for exactly 1 unit
df['unit_price'] = df['sales_amount']
print("Derived column 'unit_price' created (assumming quantity =1).")
# Out:
# Derived column 'unit_price' created (assumming quantity =1).

# %%
# T4: Categorical Transformation (Creating a Sales Tier based on amount)

# 1. Define the list of confitions (must be Boolean arrays/Series)
conditions = [
    df['sales_amount'] >= 500,
    df['sales_amount'] >= 100
]

# 2. Define list of values corresponding to the conditions
choices = [
    'High Value',
    'Low Value'
]

# 3. Apply np.select: The "default" argument handles all cases that don't meet the conditions (i.e. less than 100)
df['sales_tier'] = np.select(conditions,choices,default='Low Value')

print('Categorical transformation "sales_tiers" created using the np.select')
# Out:
# Categorical transformation "sales_tiers" created using the np.select

# %%
# T5: Filtering (Basic Data Quality Checks)
# remove rows where SalesAmount is less than or equal to 0

initial_rows = len(df)
df = df[df['sales_amount'] > 0]
rows_removed = initial_rows - len(df)
print(f"Data filtered: Removed {rows_removed} rows with non-positive sales amounts")
# Out:
# Data filtered: Removed 3 rows with non-positive sales amounts

# %% [markdown]
# # LOAD

# %%
df_load = df[[
    'order_id', 'product', 'category', 'sales_amount', 'order_date',
    'region', 'customer_name', 'unit_price', 'sales_tier'
]]

# %%
# Convert the DataFrame to a list of tuples for psycopg2's execute_batch
data_tuples = [tuple(row) for row in df_load.values]

# %%
# Define the INSERT query structure
cols = ', '.join(df_load.columns)
placeholders = ', '.join(['%s'] * len(df_load.columns))

# %%
# Define columns to update (all except the unique key 'order_id')
update_cols = [col for col in df_load.columns if col not in ['order_id']]

# %%
set_clause = ', '.join([f'{col} = EXCLUDED.{col}' for col in update_cols])

# %%
set_clause
# Out:
# 'product = EXCLUDED.product, category = EXCLUDED.category, sales_amount = EXCLUDED.sales_amount, order_date = EXCLUDED.order_date, region = EXCLUDED.region, customer_name = EXCLUDED.customer_name, unit_price = EXCLUDED.unit_price, sales_tier = EXCLUDED.sales_tier'

# %%
insert_query = sql.SQL(
    f"""
    INSERT INTO {TARGET_TABLE} ({cols})
    VALUES ({placeholders})
    ON CONFLICT (order_id)
    DO UPDATE SET {set_clause}
"""
)

# %%
try:
    with conn.cursor() as cur:
        # Use execute_batch for efficient bulk insertion
        extras.execute_batch(cur, insert_query, data_tuples)
        conn.commit()
        print(f'Successfully attempted to load {len(data_tuples)} records into {TARGET_TABLE}. Conflicting records were updated')

except psycopg2.Error as e:
    print(f'Error during data loading: {e}')
    conn.rollback()

finally:
    if conn:
        conn.close()
        print("Database connection closed")

print('\n--- ETL Process Complete ---')
# Out:
# Successfully attempted to load 9 records into etl_transformed_sales. Conflicting records were updated
# Database connection closed
#
# --- ETL Process Complete ---
